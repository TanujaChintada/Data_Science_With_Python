# %%
import matplotlib.pyplot as plt
import numpy as np
data=[10,20,30,40,50]
plt.boxplot(data)
plt.show()

# %%
data1=[150,250,450,550,750]
data2=[100,200,400,500,700]
data=[data1,data2]
plt.boxplot(data)
plt.show()

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*1000,columns=['A','B','C','D','E'])
print(df)
df.plot(kind='box')
# Out:
#             A           B           C           D           E
# 0  320.289217  367.985770  243.875341  904.186124  611.557541
# 1  628.349252  418.873694  621.969217  964.943235  293.290835
# 2  297.162207  245.497762  315.902719  265.788334  695.199057
# 3  945.594883  651.791054  928.700592  181.292493  174.318431
# 4  102.717389  537.376546  433.280571  953.175315  893.178368
# 5  915.001707  365.733905  350.237996  555.940149  110.957360
# 6  533.035724  217.876676  188.988724  768.399247  931.745487
# 7  275.664138  380.412560   13.973797  775.122063   82.535653
# 8  110.056553  691.086357  875.037958  118.219041  947.561199
# 9  908.921306  213.667569  502.164768  200.149572  368.334085
# <AxesSubplot:>

# %%
import numpy as np 
import pandas as pd
df=pd.DataFrame(np.random.rand(20,10)*100,columns=['@','$','*','%','!','a','b','c','d','e'])
print(df)
df.plot.box()
# Out:
#             @          $          *          %          !          a  \
# 0   74.578350  78.112511  19.563027  34.211718  11.762142  16.861592
# 1   40.950766  99.520504  41.838885  40.053394  21.663683  23.098885
# 2   28.778332  56.463866  40.093914  36.684650   5.051956  63.764519
# 3   12.558988  78.977333  69.975515   9.095167  28.347092  94.971845
# 4   77.429119  84.474689  21.165207   1.904980   4.498231  89.756104
# 5   25.805293  67.072185   0.175494  42.732937  22.240059  41.275843
# 6   23.170221  85.588813  87.314023  18.775478  89.625514  27.122854
# 7   88.795596  67.568142   6.192978  84.076181  59.935083  46.551151
# 8   63.125673  95.802217   4.146963  55.980719   2.562762  18.404698
# 9   71.215645  24.036075  64.959806  33.544875  76.127460  63.071478
# 10  38.373031  37.926486   5.571382  45.551820  40.079736  65.963976
# 11  81.866562  70.506059  52.146278  41.633416  20.057329  48.425061
# 12  83.659735  44.124028  54.134347  84.150018   3.409663  14.715991
# ...

# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*100,columns=[1,2,3,4,5])
df.plot(kind='box')
# Out:
# <AxesSubplot:>
