# %%
import matplotlib.pyplot as plt
import numpy as np
x=[13,8,10,6,15,17]
y=[10,20,29,40,36,25]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[13,8,10,6,15,17]
y=[10,20,29,40,36,25]
plt.plot(x,y,marker='s',mec='y',color='r')

# %%
plt.scatter(x,y)

# %%
# scatter line with extra parameter
# marker,edgecolor
plt.scatter(x,y,marker='<',edgecolor='b')

# %%
plt.scatter(x,y,marker="*",edgecolor="hotpink",color="r")

# %%
plt.scatter(x,y,marker="3",edgecolor="b",color="r")
# Out:
# C:\Users\Tanuja Chintada\AppData\Local\Temp\ipykernel_6888\630298471.py:1: UserWarning: You passed a edgecolor/edgecolors ('b') for an unfilled marker ('3').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x,y,marker="3",edgecolor="b",color="r")

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[13,8,10,6,15,17]
y=[10,20,29,40,36,25]
plt.scatter(x,y,marker="s",s=30,edgecolor="g",color='hotpink')

# %%
x=np.random.rand(40)
y=np.random.rand(40)
colors=np.random.rand(40)
plt.scatter(x,y,s=2*100,c=colors)

# %%
colors=np.random.rand(40)
plt.scatter(x,y,s=10*20)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("alpha,transparency")
x=np.random.rand(60)
print(x)
y=np.random.rand(60)
print(y)
colors=np.random.rand(60)
plt.scatter(x,y,c=colors,s=2*1000,alpha=0.2)
# Out:
# alpha,transparency
# [0.87781912 0.31460765 0.6529666  0.06096964 0.96406246 0.86824928
#  0.62798691 0.1042371  0.85908189 0.54507861 0.19963478 0.4677988
#  0.0736837  0.95423734 0.38894052 0.87726315 0.51880946 0.59287058
#  0.84217038 0.18841864 0.01617242 0.54654458 0.58420999 0.50556049
#  0.06542672 0.92903814 0.74917299 0.30745418 0.88622148 0.82247589
#  0.35722124 0.88949684 0.62386781 0.23892648 0.50916019 0.10543997
#  0.24583008 0.56288447 0.79261674 0.27429701 0.84447887 0.41941236
#  0.79758723 0.55907522 0.97634436 0.19472628 0.65406305 0.17401359
#  0.85801226 0.94225039 0.76562694 0.14979025 0.40757663 0.46922649
#  0.85055277 0.8210304  0.1658829  0.57936989 0.91500005 0.48242965]
# [0.95044517 0.66915395 0.19333011 0.85770411 0.9148358  0.2900738
#  0.27124796 0.33907505 0.10821888 0.56596364 0.89805723 0.98135402
#  0.08177592 0.28305719 0.58404659 0.37971947 0.27480401 0.57494258
#  0.17275296 0.059907   0.4948263  0.91873543 0.48148187 0.0151086
# ...

# %%
x=np.random.rand(40)
y=np.random.rand(40)
cols=np.random.rand(40)
plt.scatter(x,y,c=cols,marker="*",s=2*500,alpha=0.6)

# %%
x=np.random.rand(40)
y=np.random.rand(40)
cols=np.random.rand(40)
plt.scatter(x,y,c=cols,s=2*500,marker="s",alpha=0.3)
