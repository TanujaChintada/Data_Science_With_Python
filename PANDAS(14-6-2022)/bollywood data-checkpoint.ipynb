# %%
import pandas as pd
df=pd.read_csv("bollywood.csv")
df
df.sample(10)                 # 10 random rows
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 32     33    23-May-14                    Heropanti          HS    Romance
# 60     61     9-May-14                      Mastram          HS     Comedy
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 6       7    19-Sep-14                Daawat-E-Ishq           N     Comedy
# 135   136    20-Sep-13                 The Lunchbox           N     Drama
# 23     24     2-Oct-14                       Haider          FS     Drama
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 126   127    11-Oct-13                Baat Ban Gayi          FS     Comedy
# 44     45    15-Mar-13                           3G           N   Thriller
# 105   106    19-Jul-13           Ramaiya Vastavaiya           N    Romance
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#How many records are present in the dataset?
df.shape[1*0]
# Out:
# 149

# %%
#how many movies got released in each genre
geners=df.groupby(["Genre"])
print(geners.groups)
# Out:
# {' Drama ': [3, 5, 9, 23, 25, 26, 27, 29, 33, 34, 40, 49, 55, 56, 58, 63, 69, 70, 74, 76, 81, 86, 89, 101, 102, 104, 118, 120, 127, 128, 133, 134, 135, 139, 141], 'Action': [15, 22, 35, 36, 41, 43, 48, 54, 61, 77, 78, 91, 92, 100, 107, 119, 130, 136, 138, 143, 148], 'Action ': [10, 13, 21], 'Comedy': [2, 4, 6, 7, 8, 14, 17, 18, 19, 39, 46, 47, 52, 57, 59, 60, 65, 72, 75, 79, 84, 85, 87, 95, 96, 111, 112, 115, 124, 125, 126, 129, 132, 144, 146, 147], 'Romance': [0, 11, 12, 24, 32, 37, 42, 45, 50, 64, 66, 67, 80, 82, 83, 90, 97, 105, 106, 109, 110, 122, 123, 131, 142], 'Thriller': [28, 30, 31, 38, 44, 51, 53, 62, 68, 71, 73, 88, 93, 94, 98, 99, 103, 108, 113, 114, 116, 117, 121, 137, 140, 145], 'Thriller ': [1, 16, 20]}

# %%
#sort them in descending order
df.Genre.value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
df.Genre.str.strip()    #Formatting the Genre coloumn
# Out:
# 0       Romance
# 1      Thriller
# 2        Comedy
# 3         Drama
# 4        Comedy
#          ...
# 144      Comedy
# 145    Thriller
# 146      Comedy
# 147      Comedy
# 148      Action
# Name: Genre, Length: 149, dtype: object

# %%
pd.crosstab(df.Genre,df.ReleaseTime)
# Out:
# ReleaseTime  FS  HS  LW   N
# Genre
#  Drama        4   6   1  24
# Action        3   3   3  12
# Action        0   0   0   3
# Comedy        3   5   5  23
# Romance       3   3   4  15
# Thriller      4   1   1  20
# Thriller      0   0   1   2

# %%
pd.crosstab(df.MovieName,df.Genre)
# Out:
# Genre                       Drama   Action  Action   Comedy  Romance  \
# MovieName
# 2 States                         0       0        0       0        1
# 3G                               0       0        0       0        0
# ABCD _ Any Body Can Dance        1       0        0       0        0
# Aashiqui 2                       0       0        0       0        1
# Aatma                            0       0        0       0        0
# ...                            ...     ...      ...     ...      ...
# Yeh Jawaani Hai Deewani          0       0        0       0        1
# Youngistaan                      1       0        0       0        0
# Zanjeer                          0       1        0       0        0
# Zid                              0       0        0       0        0
# Zilla Ghaziabad                  0       1        0       0        0
#
# Genre                      Thriller  Thriller
# MovieName
# 2 States                          0          0
# ...

# %%
df["Release Date"] = pd.to_datetime(df["Release Date"])
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
df["month"] = df["Release Date"].dt.month

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
df.month.value_counts()
# Out:
# 1     20
# 3     19
# 5     18
# 7     16
# 2     16
# 4     11
# 9     10
# 6     10
# 11    10
# 10     9
# 8      8
# 12     2
# Name: month, dtype: int64

# %%
#Correlation between boxoffice collection and youtube likes
corr = df[['BoxOfficeCollection', 'YoutubeLikes']].corr()
corr
# Out:
#                      BoxOfficeCollection  YoutubeLikes
# BoxOfficeCollection             1.000000      0.682517
# YoutubeLikes                    0.682517      1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='Genre',y='YoutubeLikes',data=df)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='YoutubeLikes'>

# %%
df["Release Date"] = pd.to_datetime(df["Release Date"])
df[df.Budget>=30].month.value_counts()
# Out:
# 2     8
# 8     7
# 1     6
# 11    6
# 6     5
# 7     5
# 9     4
# 10    4
# 4     3
# 3     3
# 5     3
# 12    2
# Name: month, dtype: int64

# %%
# top 10 movies with maximum ROI
df['ROI'] = (df.BoxOfficeCollection - df.Budget)/df.Budget
#sorting the values and displaying top 10 movies 
df.sort_values(by='ROI').MovieName[0:10]
# Out:
# 9                 Gangoobai
# 15                  Bandook
# 53                 Sona Spa
# 3          Rajdhani Express
# 49     Kya Dilli Kya Lahore
# 121                 Satya 2
# 67             Purani Jeans
# 103          Samrat and Co.
# 30                Heartless
# 102                 Kaanchi
# Name: MovieName, dtype: object

# %%
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
#calculate average ROI based on Release Time
df.groupby(by="ReleaseTime").ROI.mean()
# Out:
# ReleaseTime
# FS    0.973853
# HS    0.850867
# LW    1.127205
# N     0.657722
# Name: ROI, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=df["Budget"] 
y=df["Budget"].value_counts()
print(y)
sns.displot(x,bins=100,edgecolor="black")
# Out:
# 10     12
# 15     10
# 30      9
# 12      9
# 5       9
# 35      8
# 50      7
# 40      5
# 24      5
# 18      4
# 20      4
# 4       4
# 25      4
# 16      3
# 11      3
# 75      3
# 27      3
# 60      3
# 2       3
# 7       3
# 100     2
# 22      2
# 6       2
# 90      2
# 85      2
# 8       2
# 36      2
# 31      2
# 21      2
# 120     1
# 26      1
# 32      1
# 13      1
# 23      1
# 14      1
# 115     1
# 29      1
# 140     1
# 33      1
# 19      1
# 70      1
# 28      1
# 48      1
# 45      1
# 42      1
# 9       1
# 3       1
# 125     1
# 150     1
# Name: Budget, dtype: int64

# %%
df['ROI'] = (df.BoxOfficeCollection - df.Budget)/df.Budget
df.loc[df["Genre"]=="Comedy"]["ROI"].plot.bar()   #ROI's between movies with comedy and drama
df.loc[df["Genre"]=="Romance"]["ROI"].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined
