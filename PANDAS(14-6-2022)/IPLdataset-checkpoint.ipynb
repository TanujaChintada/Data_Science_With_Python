# %%
import pandas as pd
df=pd.read_csv("ipl.csv")
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
# finding random rows from the dataset

# %%
df.sample(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 88       89       Raina, SK    1     IND    CSK      Batsman     710      13
# 2         3     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 70       71      Nannes, DP    3     AUS    DD+       Bowler       0       0
# 23       24     Flintoff, A    2     ENG    CSK   Allrounder    3845     226
# 77       78       Oram, JDP    2      NZ   CSK+   Allrounder    1780      60
# 107     108      Styris, SB    3      NZ    DC+   Allrounder    1586      20
# 105     106    Sreesanth, S    2     IND  KXIP+       Bowler     281      87
# 85       86  Pomersbach, LA    2     AUS  KXIP+      Batsman       0       0
# 20       21     Edwards, FH    2      WI     DC       Bowler     380     157
# 34       35   Henriques, MC    1     AUS   KKR+   Allrounder       0       0
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# ...

# %%
df.shape
# Out:
# (130, 26)

# %%
#meta data of the dataframe

# %%
list(df.columns)
# Out:
# ['Sl.NO.',
#  'PLAYER NAME',
#  'AGE',
#  'COUNTRY',
#  'TEAM',
#  'PLAYING ROLE',
#  'T-RUNS',
#  'T-WKTS',
#  'ODI-RUNS-S',
#  'ODI-SR-B',
#  'ODI-WKTS',
#  'ODI-SR-BL',
#  'CAPTAINCY EXP',
#  'RUNS-S',
#  'HS',
#  'AVE',
#  'SR-B',
#  'SIXERS',
#  'RUNS-C',
#  'WKTS',
#  'AVE-BL',
#  'ECON',
#  'SR-BL',
#  'AUCTION YEAR',
#  'BASE PRICE',
#  'SOLD PRICE']

# %%
df.transpose()
# Out:
#                        0             1            2          3    \
# Sl.NO.                   1             2            3          4
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R
# AGE                      2             2            2          1
# COUNTRY                 SA           BAN          IND        IND
# TEAM                  KXIP           RCB          KKR        CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler
# T-RUNS                   0           214          571        284
# T-WKTS                   0            18           58         31
# ODI-RUNS-S               0           657         1269        241
# ODI-SR-B               0.0         71.41        80.62      84.56
# ODI-WKTS                 0           185          288         51
# ODI-SR-BL              0.0          37.6         32.9       36.8
# CAPTAINCY EXP            0             0            0          0
# ...

# %%
df.head(5).transpose()
# Out:
#                          0             1            2          3             4
# Sl.NO.                   1             2            3          4             5
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S
# AGE                      2             2            2          1             2
# COUNTRY                 SA           BAN          IND        IND           IND
# TEAM                  KXIP           RCB          KKR        CSK           CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler       Batsman
# T-RUNS                   0           214          571        284            63
# T-WKTS                   0            18           58         31             0
# ODI-RUNS-S               0           657         1269        241            79
# ODI-SR-B               0.0         71.41        80.62      84.56         45.93
# ODI-WKTS                 0           185          288         51             0
# ...

# %%
df.tail(5).transpose()
# Out:
#                      125          126           127          128         129
# Sl.NO.               126          127           128          129         130
# PLAYER NAME    Yadav, AS  Younis Khan  Yuvraj Singh  Zaheer Khan  Zoysa, DNT
# AGE                    2            2             2            2           2
# COUNTRY              IND          PAK           IND          IND          SL
# TEAM                  DC           RR         KXIP+          MI+          DC
# PLAYING ROLE     Batsman      Batsman       Batsman       Bowler      Bowler
# T-RUNS                 0         6398          1775         1114         288
# T-WKTS                 0            7             9          288          64
# ODI-RUNS-S             0         6814          8051          790         343
# ODI-SR-B             0.0        75.78         87.58        73.55       95.81
# ODI-WKTS               0            3           109          278         108
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
# slicing and indexing of the dataframe

# %%
df[0:5]
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df[20:30]
# Out:
#     Sl.NO.    PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 20      21    Edwards, FH    2      WI    DC       Bowler     380     157
# 21      22  Fernando, CRD    2      SL    MI       Bowler     249      97
# 22      23    Fleming, SP    3      NZ   CSK      Batsman    7172       0
# 23      24    Flintoff, A    2     ENG   CSK   Allrounder    3845     226
# 24      25     Gambhir, G    2     IND   DD+      Batsman    3712       0
# 25      26    Ganguly, SC    3     IND  KKR+      Batsman    7212      32
# 26      27      Gayle, CH    2      WI  KKR+   Allrounder    6373      72
# 27      28      Gibbs, HH    3      SA    DC      Batsman    6167       0
# 28      29  Gilchrist, AC    3     AUS   DC+    W. Keeper    5570       0
# 29      30       Gony, MS    2     IND  CSK+       Bowler       0       0
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 20          73     45.62  ...   80.00       0     154     5   30.80  6.60
# ...

# %%
df[-5:]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df["PLAYER NAME"]
# Out:
# 0       Abdulla, YA
# 1      Abdur Razzak
# 2       Agarkar, AB
# 3         Ashwin, R
# 4      Badrinath, S
#            ...
# 125       Yadav, AS
# 126     Younis Khan
# 127    Yuvraj Singh
# 128     Zaheer Khan
# 129      Zoysa, DNT
# Name: PLAYER NAME, Length: 130, dtype: object

# %%
df["PLAYER NAME"][10:20]
# Out:
# 10          Bravo, DJ
# 11     Chanderpaul, S
# 12         Chawla, PP
# 13    de Villiers, AB
# 14          Dhawan, S
# 15          Dhoni, MS
# 16        Dilshan, TM
# 17          Dinda, AB
# 18         Dravid, RS
# 19        Duminy, J-P
# Name: PLAYER NAME, dtype: object

# %%
df[["PLAYER NAME","COUNTRY"]][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
# SELECTING ROWS AND  COLUMNS BY INDEXES

# %%
df.iloc[12:19,0:5]
# Out:
#     Sl.NO.      PLAYER NAME  AGE COUNTRY  TEAM
# 12      13       Chawla, PP    1     IND  KXIP
# 13      14  de Villiers, AB    2      SA   DD+
# 14      15        Dhawan, S    2     IND   MI+
# 15      16        Dhoni, MS    2     IND   CSK
# 16      17      Dilshan, TM    2      SL   DD+
# 17      18        Dinda, AB    2     IND  KKR+
# 18      19       Dravid, RS    3     IND  RCB+

# %%
# VALUE COUNTS AND CROSS TABULATIONS

# %%
df.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
df.AGE.value_counts()
# Out:
# 2    86
# 3    28
# 1    16
# Name: AGE, dtype: int64

# %%
df.COUNTRY.value_counts(normalize=True)*100
# Out:
# IND    40.769231
# AUS    16.923077
# SA     12.307692
# SL      9.230769
# PAK     6.923077
# NZ      5.384615
# WI      4.615385
# ENG     2.307692
# BAN     0.769231
# ZIM     0.769231
# Name: COUNTRY, dtype: float64

# %%
pd.crosstab(df['PLAYING ROLE'],df["AGE"])
# Out:
# AGE           1   2   3
# PLAYING ROLE
# Allrounder    4  25   6
# Batsman       5  21  13
# Bowler        7  29   8
# W. Keeper     0  11   1

# %%
df[df["COUNTRY"]=="IND"][["PLAYER NAME"]]
# Out:
#           PLAYER NAME
# 2         Agarkar, AB
# 3           Ashwin, R
# 4        Badrinath, S
# 6           Balaji, L
# 12         Chawla, PP
# 14          Dhawan, S
# 15          Dhoni, MS
# 17          Dinda, AB
# 18         Dravid, RS
# 24         Gambhir, G
# 25        Ganguly, SC
# 29           Gony, MS
# 30    Harbhajan Singh
# 39         Jadeja, RA
# 40          Jaffer, W
# 43            Kaif, M
# 46        Kamran Khan
# 47        Karthik, KD
# 48          Kartik, M
# 50           Kohli, V
# 51           Kumar, P
# 52          Kumble, A
# 54        Laxman, VVS
# 64          Mishra, A
# 65          Mithun, A
# 71          Nayar, AM
# 72           Nehra, A
# 75           Ojha, NV
# 76           Ojha, PP
# 78       Pankaj Singh
# 79          Patel, MM
# 80          Patel, PA
# 81         Pathan, IK
# 82         Pathan, YK
# 87          Powar, RR
# 88          Raina, SK
# 90           Saha, WP
# 93          Sehwag, V
# 95          Sharma, I
# 96          Sharma, J
# ...

# %%
df[df["TEAM"]=="DC"][["PLAYER NAME","SOLD PRICE"]]
# Out:
#        PLAYER NAME  SOLD PRICE
# 20     Edwards, FH      150000
# 27       Gibbs, HH      575000
# 94   Shahid Afridi      675000
# 100     Silva, LPC      100000
# 117    Vaas, WPUJC      200000
# 125      Yadav, AS      750000
# 129     Zoysa, DNT      110000

# %%
# SORTING DATAFRAME BY COLUMN VALUES

# %%
df[['PLAYER NAME', 'SOLD PRICE']].sort_values('SOLD PRICE')[0:5]
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000

# %%
#SORTING DATAFRAME BY USING  COLUMN VALUES

# %%
import pandas as pd
df = pd.read_csv("ipl.csv")
df[["PLAYER NAME","SOLD PRICE"]].sort_values("SOLD PRICE")
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000
# ..             ...         ...
# 113     Tiwary, SS     1600000
# 111  Tendulkar, SR     1800000
# 50        Kohli, V     1800000
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
#
# [130 rows x 2 columns]

# %%
df[["PLAYER NAME","BASE PRICE"]].sort_values("BASE PRICE",ascending=False)[3:9]
# Out:
#        PLAYER NAME  BASE PRICE
# 15       Dhoni, MS      400000
# 127   Yuvraj Singh      400000
# 18      Dravid, RS      400000
# 110   Taylor, LRPL      400000
# 93       Sehwag, V      400000
# 111  Tendulkar, SR      400000

# %%
#CREATING NEW COLUMNS

# %%
df["premium"] = df["SOLD PRICE"] - df["BASE PRICE"]
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
y =  df[["PLAYER NAME","BASE PRICE","SOLD PRICE","premium"]][0:5]
y
# Out:
#     PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 0   Abdulla, YA       50000       50000        0
# 1  Abdur Razzak       50000       50000        0
# 2   Agarkar, AB      200000      350000   150000
# 3     Ashwin, R      100000      850000   750000
# 4  Badrinath, S      100000      800000   700000

# %%
x=df[["PLAYER NAME","BASE PRICE","SOLD PRICE","premium"]].sort_values("premium",ascending=False)
x
# Out:
#        PLAYER NAME  BASE PRICE  SOLD PRICE  premium
# 50        Kohli, V      150000     1800000  1650000
# 113     Tiwary, SS      100000     1600000  1500000
# 127   Yuvraj Singh      400000     1800000  1400000
# 111  Tendulkar, SR      400000     1800000  1400000
# 93       Sehwag, V      400000     1800000  1400000
# ..             ...         ...         ...      ...
# 102      Smith, DR      100000      100000        0
# 73      Noffke, AA       20000       20000        0
# 100     Silva, LPC      100000      100000        0
# 74        Ntini, M      200000      200000        0
# 0      Abdulla, YA       50000       50000        0
#
# [130 rows x 4 columns]

# %%
#GROUPING AND AGGREGATING

# %%
df.groupby("AGE")["SOLD PRICE"].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %%
df.groupby("PLAYING ROLE")["BASE PRICE"].mean()
# Out:
# PLAYING ROLE
# Allrounder    178428.571429
# Batsman       232051.282051
# Bowler        166931.818182
# W. Keeper     195833.333333
# Name: BASE PRICE, dtype: float64

# %%
df.groupby("AGE")["SOLD PRICE"].mean().reset_index()
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df.groupby(["AGE","PLAYING ROLE"])["BASE PRICE"].mean().reset_index()
# Out:
#     AGE PLAYING ROLE     BASE PRICE
# 0     1   Allrounder  143750.000000
# 1     1      Batsman  145000.000000
# 2     1       Bowler  117142.857143
# 3     2   Allrounder  178800.000000
# 4     2      Batsman  241190.476190
# 5     2       Bowler  154310.344828
# 6     2    W. Keeper  186363.636364
# 7     3   Allrounder  200000.000000
# 8     3      Batsman  250769.230769
# 9     3       Bowler  256250.000000
# 10    3    W. Keeper  300000.000000

# %%
import pandas as pd
df=pd.read_csv("ipl.csv")
x=df.groupby("AGE")["SOLD PRICE"].mean()
print(x)
y=df.groupby("PLAYING ROLE")["SOLD PRICE"].mean()
y
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64
# PLAYING ROLE
# Allrounder    519571.428571
# Batsman       647435.897436
# Bowler        419977.272727
# W. Keeper     487083.333333
# Name: SOLD PRICE, dtype: float64

# %%
z = y.merge(x,
           on="AGE",
           how="outer")
print(z)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 z = y.merge(x,
#       2            on="AGE",
#       3            how="outer")
#       4 print(z)
#
# File ~\Downloads\New folder\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'merge'

# %%
df[df["SIXERS"]>80][["PLAYER NAME","SIXERS","PLAYING ROLE"]]
# Out:
#       PLAYER NAME  SIXERS PLAYING ROLE
# 26      Gayle, CH     129   Allrounder
# 28  Gilchrist, AC      86    W. Keeper
# 82     Pathan, YK      81   Allrounder
# 88      Raina, SK      97      Batsman
# 97     Sharma, RG      82      Batsman

# %%
import pandas as pd
df=pd.read_csv("ipl.csv")
df.drop("T-RUNS",inplace = True,axis=1)
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman       0
# ..      ...           ...  ...     ...    ...          ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0
# 126     127   Younis Khan    2     PAK     RR      Batsman       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# 0             0      0.00         0  ...    0.00       0     307    15
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [75], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 import inline
#
# ModuleNotFoundError: No module named 'inline'

# %%
import warnings
warnings.filterwarnings('ignore')
